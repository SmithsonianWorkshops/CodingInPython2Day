# %%
from pandas import DataFrame, read_csv

# %%
import pandas as pd
import bokeh

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)

# %%
# The inital set of baby names and bith rates
names = ['Bob','Jessica','Mary','John','Mel']
births = [968, 155, 77, 578, 973]

# %%
names = ["Mary", "Sue", "John", "Eric", "Jordan", "Melanie"]
height = [64, 70, 70, 76, 72, 65]

# %%
zip?

# %%
height_data = list(zip(names, height))

# %%
height_data

# %%
df = pd.DataFrame(data = height_data, columns=["Names", "Height_inches"])

# %%
df

# %%
df.dtypes

# %%
# Create graph
df['Height_inches'].plot()

# Maximum value in the data set
MaxValue = df['Height_inches'].max()

# Name associated with the maximum value
MaxName = df['Names'][df['Height_inches'] == df['Height_inches'].max()].values

# Text to display on graph
Text = str(MaxValue) + " - " + MaxName

# Add text to graph
plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')

print("The most popular name")
df[df['Height_inches'] == df['Height_inches'].max()]
#Sorted.head(1) can also be used

# %%
for i in height_data:
    print(i)

# %%
for i in height_data:
    print(i[1])

# %%
mean_height = df["Height_inches"].mean()

# %%
mean_height

# %%
median_height = df["Height_inches"].median()

# %%
median_height

# %%
descriptives_height = df["Height_inches"].describe()

# %%
descriptives_height

# %%
BabyDataSet = list(zip(names,births))
BabyDataSet

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
df

# %%
df.to_csv?

# %%
df.to_csv('births1880.csv',index=False,header=False)

# %%
Location = 'cfa/cfa_challenge.csv'
df = pd.read_csv(Location)

# %%
df

# %%
df.dtypes

# %%
Location = "births1880.csv"

# %%
df = pd.read_csv(Location)

# %%
df

# %%
df = pd.read_csv(Location, names=["Names", "Births"])

# %%
df

# %%
# Create graph
df['Births'].plot()

# Maximum value in the data set
MaxValue = df['Births'].max()

# Name associated with the maximum value
MaxName = df['Names'][df['Births'] == df['Births'].max()].values

# Text to display on graph
Text = str(MaxValue) + " - " + MaxName

# Add text to graph
plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')

print("The most popular name")
df[df['Births'] == df['Births'].max()]
#Sorted.head(1) can also be used

# %%
df = pd.read_csv("gender_height.csv")

# %%
df
# Out:
#     Gender  Height
# 0        1      67
# 1        1      67
# 2        1      67
# 3        1      60
# 4        1      68
# 5        1      64
# 6        1      69
# 7        1      71
# 8        1      67
# 9        1      67
# 10       1      66
# 11       1      63
# 12       1      67
# 13       1      62
# 14       1      66
# 15       1      70
# 16       1      67
# 17       1      61
# 18       1      68
# 19       1      67
# 20       1      68
# 21       1      64
# 22       1      69
# 23       1      67
# 24       1      70
# 25       1      72
# 26       1      61
# 27       1      67
# 28       1      69
# 29       1      68
# ..     ...     ...
# 70       2      73
# 71       2      72
# 72       2      65
# 73       2      71
# 74       2      74
# 75       2      69
# 76       2      73
# 77       2      69
# 78       2      71
# 79       2      67
# 80       2      74
# 81       2      70
# 82       2      70
# 83       2      70
# 84       2      74
# ...

# %%
df["Gender"].replace(1, "female")
# Out:
# 0     female
# 1     female
# 2     female
# 3     female
# 4     female
# 5     female
# 6     female
# 7     female
# 8     female
# 9     female
# 10    female
# 11    female
# 12    female
# 13    female
# 14    female
# 15    female
# 16    female
# 17    female
# 18    female
# 19    female
# 20    female
# 21    female
# 22    female
# 23    female
# 24    female
# 25    female
# 26    female
# 27    female
# 28    female
# 29    female
#        ...
# 70         2
# 71         2
# 72         2
# 73         2
# 74         2
# 75         2
# 76         2
# 77         2
# 78         2
# 79         2
# 80         2
# 81         2
# 82         2
# 83         2
# 84         2
# 85         2
# 86         2
# 87         2
# 88         2
# 89         2
# 90         2
# 91         2
# 92         2
# 93         2
# 94         2
# 95         2
# 96         2
# 97         2
# 98         2
# 99         2
# Name: Gender, dtype: object

# %%
df
# Out:
#     Gender  Height
# 0        1      67
# 1        1      67
# 2        1      67
# 3        1      60
# 4        1      68
# 5        1      64
# 6        1      69
# 7        1      71
# 8        1      67
# 9        1      67
# 10       1      66
# 11       1      63
# 12       1      67
# 13       1      62
# 14       1      66
# 15       1      70
# 16       1      67
# 17       1      61
# 18       1      68
# 19       1      67
# 20       1      68
# 21       1      64
# 22       1      69
# 23       1      67
# 24       1      70
# 25       1      72
# 26       1      61
# 27       1      67
# 28       1      69
# 29       1      68
# ..     ...     ...
# 70       2      73
# 71       2      72
# 72       2      65
# 73       2      71
# 74       2      74
# 75       2      69
# 76       2      73
# 77       2      69
# 78       2      71
# 79       2      67
# 80       2      74
# 81       2      70
# 82       2      70
# 83       2      70
# 84       2      74
# ...

# %%
df["Gender"] = df["Gender"].replace(1, "female")

# %%
df
# Out:
#     Gender  Height
# 0   female      67
# 1   female      67
# 2   female      67
# 3   female      60
# 4   female      68
# 5   female      64
# 6   female      69
# 7   female      71
# 8   female      67
# 9   female      67
# 10  female      66
# 11  female      63
# 12  female      67
# 13  female      62
# 14  female      66
# 15  female      70
# 16  female      67
# 17  female      61
# 18  female      68
# 19  female      67
# 20  female      68
# 21  female      64
# 22  female      69
# 23  female      67
# 24  female      70
# 25  female      72
# 26  female      61
# 27  female      67
# 28  female      69
# 29  female      68
# ..     ...     ...
# 70       2      73
# 71       2      72
# 72       2      65
# 73       2      71
# 74       2      74
# 75       2      69
# 76       2      73
# 77       2      69
# 78       2      71
# 79       2      67
# 80       2      74
# 81       2      70
# 82       2      70
# 83       2      70
# 84       2      74
# ...

# %%
df["Gender"] = df["Gender"].replace(2, "male")

# %%
df
# Out:
#     Gender  Height
# 0   female      67
# 1   female      67
# 2   female      67
# 3   female      60
# 4   female      68
# 5   female      64
# 6   female      69
# 7   female      71
# 8   female      67
# 9   female      67
# 10  female      66
# 11  female      63
# 12  female      67
# 13  female      62
# 14  female      66
# 15  female      70
# 16  female      67
# 17  female      61
# 18  female      68
# 19  female      67
# 20  female      68
# 21  female      64
# 22  female      69
# 23  female      67
# 24  female      70
# 25  female      72
# 26  female      61
# 27  female      67
# 28  female      69
# 29  female      68
# ..     ...     ...
# 70    male      73
# 71    male      72
# 72    male      65
# 73    male      71
# 74    male      74
# 75    male      69
# 76    male      73
# 77    male      69
# 78    male      71
# 79    male      67
# 80    male      74
# 81    male      70
# 82    male      70
# 83    male      70
# 84    male      74
# ...

# %%
des_stats = df['Height'].describe()

# %%
des_stats
# Out:
# count    100.000000
# mean      69.410000
# std        4.109843
# min       60.000000
# 25%       67.000000
# 50%       69.000000
# 75%       72.250000
# max       79.000000
# Name: Height, dtype: float64

# %%
from bokeh.charts import Histogram, Line, BoxPlot, output_notebook, show

# %%
hist = Histogram(df, values='Height', title="Distribution of Height", plot_width=400)

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1f2447ac-ef42-4186-976d-55334a3bb858">Loading BokehJS ...</span>
#     </div>

# %%
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0225478f-51c2-4dea-9e42-acbcda806d4a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
hist = Histogram(df, values='Height', title="Distribution of Height", plot_width=400, bins=13)

# %%
show(hist)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ecb27dca-f1b7-4e24-9e73-60a547d3742e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
hist2 = Histogram(df, values='Height', label='Gender', color='Gender',
                  title="Height by Gender", plot_width=400)

# %%
show(hist2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f368cdbb-f2fc-447b-b282-cfa08644bed7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
hist2 = Histogram(df, values='Height', label='Gender', color='Gender',
                  title="Height by Gender", plot_width=400, bins=13)

# %%
show(hist2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0f8a9696-fdef-4565-9ec3-4e0f3546ae53"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
by_gender = df.groupby("Gender")

# %%
by_gender

# %%
by_gender.describe()
# Out:
#                  Height
# Gender
# female count  50.000000
#        mean   66.400000
#        std     2.920721
#        min    60.000000
#        25%    65.000000
#        50%    67.000000
#        75%    68.000000
#        max    72.000000
# male   count  50.000000
#        mean   72.420000
#        std     2.665655
#        min    65.000000
#        25%    71.000000
#        50%    72.500000
#        75%    74.000000
#        max    79.000000

# %%
line = Line(df, title="line", legend="top_left", ylabel='Height')

# %%
show(line)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="16c7571e-70ab-46e1-af67-f087c1abee28"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
box = BoxPlot(df, values='Height', label='Gender', title="Heights", plot_width=400)

# %%
show(box)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0107997b-7557-4894-99e1-f164ee82c177"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
box2 = BoxPlot(df, values='Height', label='Gender', color='Gender',
               title="Height by Gender", plot_width=400)

# %%
show(box2)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f8fd1f86-61a7-4333-9f39-f3e4c819b7a0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
from scipy.stats import ttest_ind

# %%
male_heights = df[df["Gender"]=="male"]

# %%
male_heights
# Out:
#    Gender  Height
# 50   male      72
# 51   male      74
# 52   male      75
# 53   male      71
# 54   male      71
# 55   male      68
# 56   male      75
# 57   male      75
# 58   male      74
# 59   male      70
# 60   male      74
# 61   male      74
# 62   male      79
# 63   male      72
# 64   male      72
# 65   male      75
# 66   male      72
# 67   male      76
# 68   male      76
# 69   male      74
# 70   male      73
# 71   male      72
# 72   male      65
# 73   male      71
# 74   male      74
# 75   male      69
# 76   male      73
# 77   male      69
# 78   male      71
# 79   male      67
# 80   male      74
# 81   male      70
# 82   male      70
# 83   male      70
# 84   male      74
# 85   male      74
# 86   male      74
# 87   male      70
# 88   male      74
# 89   male      73
# 90   male      69
# 91   male      72
# 92   male      69
# 93   male      74
# 94   male      71
# 95   male      72
# 96   male      74
# 97   male      75
# 98   male      77
# ...

# %%
female_heights = df[df["Gender"]=="female"]

# %%
female_heights
# Out:
#     Gender  Height
# 0   female      67
# 1   female      67
# 2   female      67
# 3   female      60
# 4   female      68
# 5   female      64
# 6   female      69
# 7   female      71
# 8   female      67
# 9   female      67
# 10  female      66
# 11  female      63
# 12  female      67
# 13  female      62
# 14  female      66
# 15  female      70
# 16  female      67
# 17  female      61
# 18  female      68
# 19  female      67
# 20  female      68
# 21  female      64
# 22  female      69
# 23  female      67
# 24  female      70
# 25  female      72
# 26  female      61
# 27  female      67
# 28  female      69
# 29  female      68
# 30  female      69
# 31  female      72
# 32  female      66
# 33  female      67
# 34  female      66
# 35  female      67
# 36  female      69
# 37  female      64
# 38  female      64
# 39  female      63
# 40  female      68
# 41  female      66
# 42  female      65
# 43  female      60
# 44  female      70
# 45  female      65
# ...

# %%
ttest_ind(male_heights['Height'], female_heights['Height'])
# Out:
# Ttest_indResult(statistic=10.765002322370973, pvalue=2.66630615826245e-18)
